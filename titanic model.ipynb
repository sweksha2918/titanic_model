# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
df.isnull()
# Out:
#      Survived  Pclass    Sex    Age  SibSp  Parch   Fare  Cabin  Embarked
# 0       False   False  False  False  False  False  False   True     False
# 1       False   False  False  False  False  False  False  False     False
# 2       False   False  False  False  False  False  False   True     False
# 3       False   False  False  False  False  False  False  False     False
# 4       False   False  False  False  False  False  False   True     False
# ..        ...     ...    ...    ...    ...    ...    ...    ...       ...
# 886     False   False  False  False  False  False  False   True     False
# 887     False   False  False  False  False  False  False  False     False
# 888     False   False  False   True  False  False  False   True     False
# 889     False   False  False  False  False  False  False  False     False
# 890     False   False  False  False  False  False  False   True     False
#
# [891 rows x 9 columns]

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df['Cabin'].isnull().value_counts()
# Out:
# True     687
# False    204
# Name: Cabin, dtype: int64

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=df['Sex'],y=df['Age'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x=df['SibSp'],y=df['Age'])
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Age'>

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
sns.boxplot(x=df['Parch'],y=df['Age'])
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Age'>

# %%
df['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df[df['Parch']==0]['Age'].mean()
# Out:
# 32.17850287907869

# %%
df[df['Parch']==1]['Age'].mean()
# Out:
# 24.422

# %%
df[df['Parch']==2]['Age'].mean()
# Out:
# 17.216911764705884

# %%
df[df['Parch']==3]['Age'].mean()
# Out:
# 33.2

# %%
df[df['Parch']==4]['Age'].mean()
# Out:
# 44.5

# %%
df[df['Parch']==6]['Age'].mean()
# Out:
# 43.0

# %%
def impuet_age(cols):
    age=cols[0]
    parch=cols[1]
    if pd.isnull(age):
        if parch==0:
            return 32
        elif parch==1:
            return 24
        elif parch==2:
            return 17
        elif parch==3:
            return 33
        elif parch==4:
            return 44
        else:
            return 43
    else:
        return age

# %%
df['Age']=df[['Age','Parch']].apply(impuet_age,axis=1)

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  17.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df['Age'].isnull().value_counts()
# Out:
# False    891
# Name: Age, dtype: int64

# %%
sex=pd.get_dummies(df['Sex'],drop_first=True)

# %%
sex
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
embarked=pd.get_dummies(df['Embarked'],drop_first=True)

# %%
embarked
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [891 rows x 2 columns]

# %%
df=pd.concat([df,sex,embarked],axis=1)

# %%
df.drop(['Sex','Embarked'],axis=1,inplace=True)

# %%
x=df.drop('Survived',axis=1)

# %%
x
# Out:
#      Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0         3  22.0      1      0   7.2500     1  0  1
# 1         1  38.0      1      0  71.2833     0  0  0
# 2         3  26.0      0      0   7.9250     0  0  1
# 3         1  35.0      1      0  53.1000     0  0  1
# 4         3  35.0      0      0   8.0500     1  0  1
# ..      ...   ...    ...    ...      ...   ... .. ..
# 886       2  27.0      0      0  13.0000     1  0  1
# 887       1  19.0      0      0  30.0000     0  0  1
# 888       3  17.0      1      2  23.4500     0  0  1
# 889       1  26.0      0      0  30.0000     1  0  0
# 890       3  32.0      0      0   7.7500     1  1  0
#
# [891 rows x 8 columns]

# %%
y=df['Survived']

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=103)

# %%
x_train
# Out:
#      Pclass    Age  SibSp  Parch      Fare  male  Q  S
# 417       2  18.00      0      2   13.0000     0  0  1
# 305       1   0.92      1      2  151.5500     1  0  1
# 127       3  24.00      0      0    7.1417     1  0  1
# 130       3  33.00      0      0    7.8958     1  0  0
# 465       3  38.00      0      0    7.0500     1  0  1
# ..      ...    ...    ...    ...       ...   ... .. ..
# 825       3  32.00      0      0    6.9500     1  1  0
# 347       3  32.00      1      0   16.1000     0  0  1
# 787       3   8.00      4      1   29.1250     1  1  0
# 73        3  26.00      1      0   14.4542     1  0  0
# 775       3  18.00      0      0    7.7500     1  0  1
#
# [623 rows x 8 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
y_train
# Out:
# 417    1
# 305    1
# 127    1
# 130    0
# 465    0
#       ..
# 825    0
# 347    1
# 787    0
# 73     0
# 775    0
# Name: Survived, Length: 623, dtype: int64

# %%
x_train
# Out:
#      Pclass    Age  SibSp  Parch      Fare  male  Q  S
# 417       2  18.00      0      2   13.0000     0  0  1
# 305       1   0.92      1      2  151.5500     1  0  1
# 127       3  24.00      0      0    7.1417     1  0  1
# 130       3  33.00      0      0    7.8958     1  0  0
# 465       3  38.00      0      0    7.0500     1  0  1
# ..      ...    ...    ...    ...       ...   ... .. ..
# 825       3  32.00      0      0    6.9500     1  1  0
# 347       3  32.00      1      0   16.1000     0  0  1
# 787       3   8.00      4      1   29.1250     1  1  0
# 73        3  26.00      1      0   14.4542     1  0  0
# 775       3  18.00      0      0    7.7500     1  0  1
#
# [623 rows x 8 columns]

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_test
# Out:
#      Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 188       3  40.0      1      1  15.5000     1  1  0
# 167       3  45.0      1      4  27.9000     0  0  1
# 212       3  22.0      0      0   7.2500     1  0  1
# 395       3  22.0      0      0   7.7958     1  0  1
# 362       3  45.0      0      1  14.4542     0  0  0
# ..      ...   ...    ...    ...      ...   ... .. ..
# 748       1  19.0      1      0  53.1000     1  0  1
# 333       3  16.0      2      0  18.0000     1  0  1
# 433       3  17.0      0      0   7.1250     1  0  1
# 720       2   6.0      0      1  33.0000     0  0  1
# 511       3  32.0      0      0   8.0500     1  0  1
#
# [268 rows x 8 columns]

# %%
y_pred=model.predict(x_test)

# %%
model.predict_proba(x_test)
# Out:
# array([[0.92496506, 0.07503494],
#        [0.74707323, 0.25292677],
#        [0.86976213, 0.13023787],
#        [0.86960291, 0.13039709],
#        [0.49571157, 0.50428843],
#        [0.53738176, 0.46261824],
#        [0.05931337, 0.94068663],
#        [0.45376438, 0.54623562],
#        [0.91907478, 0.08092522],
#        [0.21210488, 0.78789512],
#        [0.2302012 , 0.7697988 ],
#        [0.15476274, 0.84523726],
#        [0.91060671, 0.08939329],
#        [0.68216399, 0.31783601],
#        [0.17560381, 0.82439619],
#        [0.93350625, 0.06649375],
#        [0.53095027, 0.46904973],
#        [0.8297438 , 0.1702562 ],
#        [0.49657815, 0.50342185],
#        [0.03459409, 0.96540591],
#        [0.91210129, 0.08789871],
#        [0.45371985, 0.54628015],
#        [0.52342339, 0.47657661],
#        [0.54498723, 0.45501277],
#        [0.23014334, 0.76985666],
#        [0.59082337, 0.40917663],
#        [0.92200662, 0.07799338],
#        [0.62349228, 0.37650772],
#        [0.9068589 , 0.0931411 ],
#        [0.84810394, 0.15189606],
#        [0.88592533, 0.11407467],
#        [0.35236234, 0.64763766],
#        [0.21845817, 0.78154183],
#        [0.05015004, 0.94984996],
#        [0.8941251 , 0.1058749 ],
#        [0.26850302, 0.73149698],
#        [0.01891721, 0.98108279],
#        [0.72724428, 0.27275572],
#        [0.65041719, 0.34958281],
#        [0.73543478, 0.26456522],
#        [0.37223644, 0.62776356],
#        [0.86601156, 0.13398844],
#        [0.8924156 , 0.1075844 ],
#        [0.96103194, 0.03896806],
#        [0.03003802, 0.96996198],
#        [0.83912493, 0.16087507],
#        [0.4276967 , 0.5723033 ],
#        [0.12371885, 0.87628115],
#        [0.31910681, 0.68089319],
#        [0.33597688, 0.66402312],
#        [0.42832421, 0.57167579],
#        [0.97153148, 0.02846852],
#        [0.85396038, 0.14603962],
#        [0.84827105, 0.15172895],
#        [0.74145468, 0.25854532],
#        [0.35092284, 0.64907716],
#        [0.80790798, 0.19209202],
#        [0.91877674, 0.08122326],
#        [0.32384654, 0.67615346],
#        [0.91198944, 0.08801056],
#        [0.94141805, 0.05858195],
#        [0.86609649, 0.13390351],
#        [0.93113445, 0.06886555],
#        [0.12341222, 0.87658778],
#        [0.1931127 , 0.8068873 ],
#        [0.98806205, 0.01193795],
#        [0.05961318, 0.94038682],
#        [0.89676851, 0.10323149],
#        [0.7365777 , 0.2634223 ],
#        [0.78728978, 0.21271022],
#        [0.25005363, 0.74994637],
#        [0.69692105, 0.30307895],
#        [0.8591955 , 0.1408045 ],
#        [0.94434567, 0.05565433],
#        [0.72629123, 0.27370877],
#        [0.19561207, 0.80438793],
#        [0.31168586, 0.68831414],
#        [0.13224349, 0.86775651],
#        [0.30279158, 0.69720842],
#        [0.8644451 , 0.1355549 ],
#        [0.66493934, 0.33506066],
#        [0.91197481, 0.08802519],
#        [0.81917275, 0.18082725],
#        [0.07531381, 0.92468619],
#        [0.87948327, 0.12051673],
#        [0.11003286, 0.88996714],
#        [0.16419099, 0.83580901],
#        [0.62299053, 0.37700947],
#        [0.78163228, 0.21836772],
#        [0.853777  , 0.146223  ],
#        [0.78728978, 0.21271022],
#        [0.97393763, 0.02606237],
#        [0.04593346, 0.95406654],
#        [0.84221297, 0.15778703],
#        [0.86199869, 0.13800131],
#        [0.84259065, 0.15740935],
#        [0.86629535, 0.13370465],
#        [0.05245226, 0.94754774],
#        [0.37745384, 0.62254616],
#        [0.95241697, 0.04758303],
#        [0.65525756, 0.34474244],
#        [0.84221297, 0.15778703],
#        [0.75939729, 0.24060271],
#        [0.9461761 , 0.0538239 ],
#        [0.65351408, 0.34648592],
#        [0.65071678, 0.34928322],
#        [0.39888234, 0.60111766],
#        [0.17937098, 0.82062902],
#        [0.29232541, 0.70767459],
#        [0.36715101, 0.63284899],
#        [0.72444034, 0.27555966],
#        [0.96187869, 0.03812131],
#        [0.77950338, 0.22049662],
#        [0.91197481, 0.08802519],
#        [0.86979857, 0.13020143],
#        [0.23051256, 0.76948744],
#        [0.17286406, 0.82713594],
#        [0.40903032, 0.59096968],
#        [0.05708589, 0.94291411],
#        [0.09158103, 0.90841897],
#        [0.933801  , 0.066199  ],
#        [0.30676935, 0.69323065],
#        [0.68584362, 0.31415638],
#        [0.85000133, 0.14999867],
#        [0.22142604, 0.77857396],
#        [0.94858299, 0.05141701],
#        [0.13292989, 0.86707011],
#        [0.93412139, 0.06587861],
#        [0.51974608, 0.48025392],
#        [0.35258265, 0.64741735],
#        [0.85309418, 0.14690582],
#        [0.06558159, 0.93441841],
#        [0.86629535, 0.13370465],
#        [0.91198084, 0.08801916],
#        [0.39610548, 0.60389452],
#        [0.86452802, 0.13547198],
#        [0.75815417, 0.24184583],
#        [0.75342539, 0.24657461],
#        [0.03787536, 0.96212464],
#        [0.91198084, 0.08801916],
#        [0.51033377, 0.48966623],
#        [0.90140813, 0.09859187],
#        [0.79900841, 0.20099159],
#        [0.44714559, 0.55285441],
#        [0.91194898, 0.08805102],
#        [0.2679062 , 0.7320938 ],
#        [0.74168965, 0.25831035],
#        [0.49034146, 0.50965854],
#        [0.86629661, 0.13370339],
#        [0.75004571, 0.24995429],
#        [0.91194898, 0.08805102],
#        [0.86629535, 0.13370465],
#        [0.23504046, 0.76495954],
#        [0.88789892, 0.11210108],
#        [0.8101887 , 0.1898113 ],
#        [0.66864733, 0.33135267],
#        [0.74820463, 0.25179537],
#        [0.91205227, 0.08794773],
#        [0.45943752, 0.54056248],
#        [0.38314317, 0.61685683],
#        [0.75564577, 0.24435423],
#        [0.91198084, 0.08801916],
#        [0.91164882, 0.08835118],
#        [0.05181368, 0.94818632],
#        [0.91204051, 0.08795949],
#        [0.933801  , 0.066199  ],
#        [0.7352272 , 0.2647728 ],
#        [0.90837078, 0.09162922],
#        [0.76206875, 0.23793125],
#        [0.91549114, 0.08450886],
#        [0.25005363, 0.74994637],
#        [0.88407853, 0.11592147],
#        [0.94425224, 0.05574776],
#        [0.79630814, 0.20369186],
#        [0.78408196, 0.21591804],
#        [0.02910938, 0.97089062],
#        [0.0961844 , 0.9038156 ],
#        [0.85634487, 0.14365513],
#        [0.7059557 , 0.2940443 ],
#        [0.87450466, 0.12549534],
#        [0.47102749, 0.52897251],
#        [0.90689984, 0.09310016],
#        [0.84273817, 0.15726183],
#        [0.0860524 , 0.9139476 ],
#        [0.91194898, 0.08805102]])

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.8097014925373134
